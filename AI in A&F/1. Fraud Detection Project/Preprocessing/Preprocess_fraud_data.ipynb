# %% [markdown]
# # Preprocess mini_fraud

# %% [markdown]
# <img src="https://i.imgur.com/4mlit9j.png" width=700 align="center">

# %% [markdown]
# ### Import libraries and data

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams.update(plt.rcParamsDefault)
# %matplotlib inline
plt.style.use('ggplot')

# %%
fraud_df = pd.read_csv("Fraud.csv")

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
fraud_df.head()
# Out:
#    step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT  9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT  1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER   181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT   181.00   C840083671         181.00            0.00
# 4     1   PAYMENT 11668.14  C2048537720       41554.00        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155            0.00            0.00        0               0
# 1  M2044282225            0.00            0.00        0               0
# 2   C553264065            0.00            0.00        1               0
# 3    C38997010        21182.00            0.00        1               0
# 4  M1230701703            0.00            0.00        0               0

# %%
fraud_df.describe()
# Out:
#             step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count 1048575.00  1048575.00     1048575.00      1048575.00      1048575.00
# mean       26.97   158666.98      874009.54       893808.90       978160.05
# std        15.62   264940.93     2971750.56      3008271.33      2296780.39
# min         1.00        0.10           0.00            0.00            0.00
# 25%        15.00    12149.07           0.00            0.00            0.00
# 50%        20.00    76343.33       16002.00            0.00       126377.21
# 75%        39.00   213761.89      136642.02       174599.99       915923.47
# max        95.00 10000000.00    38900000.00     38900000.00     42100000.00
#
#        newbalanceDest    isFraud  isFlaggedFraud
# count      1048575.00 1048575.00      1048575.00
# mean       1114197.97       0.00            0.00
# std        2416593.12       0.03            0.00
# min              0.00       0.00            0.00
# 25%              0.00       0.00            0.00
# 50%         218260.36       0.00            0.00
# 75%        1149807.51       0.00            0.00
# max       42200000.00       1.00            0.00

# %%
fraud_df.shape
# Out:
# (1048575, 11)

# %%
fraud_df = fraud_df.drop(['isFlaggedFraud'], axis=1)

# %%
# get same_value feature
def same_value(amt, oldbal):
    if amt == oldbal:
        return 1
    else:
        return 0

fraud_df['same_value'] = fraud_df.apply(lambda x: same_value(x['amount'], x['oldbalanceOrg']), axis=1)

# %%
# transform nameDest to numeric feature by only using 1st character
def nameDest_prefix(name):
    return name[:1]
  
fraud_df['prefix'] = fraud_df['nameDest'].apply(nameDest_prefix)

# Get one hot encoding of columns
one_hot = pd.get_dummies(fraud_df['prefix'], dtype=int)
# Drop column as it is now encoded
fraud_df = fraud_df.drop(['nameDest','prefix'],axis = 1)
# Join the encoded dataset
fraud_df = fraud_df.join(one_hot)
fraud_df.head(200)
# Out:
#      step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1       1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2       1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3       1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4       1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5       1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6       1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7       1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8       1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9       1     DEBIT   5337.77   C712410124       41720.00        36382.23
# 10      1     DEBIT   9644.94  C1900366749        4465.00            0.00
# 11      1   PAYMENT   3099.97   C249177573       20771.00        17671.03
# 12      1   PAYMENT   2560.74  C1648232591        5070.00         2509.26
# 13      1   PAYMENT  11633.76  C1716932897       10127.00            0.00
# 14      1   PAYMENT   4098.78  C1026483832      503264.00       499165.22
# 15      1  CASH_OUT 229133.94   C905080434       15325.00            0.00
# 16      1   PAYMENT   1563.82   C761750706         450.00            0.00
# 17      1   PAYMENT   1157.86  C1237762639       21156.00        19998.14
# 9          41898.00        40348.79        0           0  1  0
# 10         10845.00       157982.12        0           0  1  0
# 11             0.00            0.00        0           0  0  1
# 12             0.00            0.00        0           0  0  1
# 13             0.00            0.00        0           0  0  1
# 14             0.00            0.00        0           0  0  1
# 15          5083.00        51513.44        0           0  1  0
# 16             0.00            0.00        0           0  0  1
# 17             0.00            0.00        0           0  0  1
# 18             0.00            0.00        0           0  0  1
# 19         22425.00            0.00        0           0  1  0
# 20             0.00            0.00        0           0  0  1
# 21         29832.00        16896.70        0           0  1  0
# 22         10330.00            0.00        0           0  1  0
# 23             0.00            0.00        0           0  0  1
# 24          6267.00      2719172.89        0           0  1  0
# 25             0.00            0.00        0           0  0  1
# 26             0.00            0.00        0           0  0  1
# 27             0.00            0.00        0           0  0  1
# 28             0.00            0.00        0           0  0  1
# 29             0.00            0.00        0           0  0  1
# ..              ...             ...      ...         ... .. ..
# 170        80341.00       557537.26        0           0  1  0
# 171      6048647.54     19200000.00        0           0  1  0
# 172        44853.00           96.88        0           0  1  0
# 173       435962.90        46820.71        0           0  1  0
# 174        99217.58            0.00        0           0  1  0
# 175        24553.00            0.00        0           0  1  0
# 176        60169.00       215851.28        0           0  1  0
# 177      6093090.62     19200000.00        0           0  1  0
# 178        49161.00       130747.56        0           0  1  0
# 179        63553.00            0.00        0           0  1  0
# 180       203679.00      2107965.39        0           0  1  0
# 181       127206.90        64106.18        0           0  1  0
# 182       292728.00        55974.56        0           0  1  0
# 183        87408.00        63112.23        0           0  1  0
# 184      1161088.31      1412484.09        0           0  1  0
# 185        52251.58            0.00        0           0  1  0
# 186         9471.00       593737.38        0           0  1  0
# 187       404814.81        55974.56        0           0  1  0
# 188       272624.50       971418.91        0           0  1  0
# 189       564572.76      1254956.07        0           0  1  0
# 190       342149.20      3461666.05        0           0  1  0
# 191       317952.89      2719172.89        0           0  1  0
# 192       443057.43            0.00        0           0  1  0
# 193       278846.75      1186556.81        0           0  1  0
# 194       464326.57       971418.91        0           0  1  0
# 195      1442298.03        22190.99        0           0  1  0
# 196       154606.00      1363368.51        0           0  1  0
# 197       657983.89      6453430.91        0           0  1  0
# 198       544481.28      3461666.05        0           0  1  0
# 199       394124.51      2107965.39        0           0  1  0
#
# [200 rows x 12 columns]

# %%
fraud_df.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# same_value          int64
# C                   int32
# M                   int32
# dtype: object

# %%
# Check for null values
fraud_df.isnull().values.any()
# Out:
# False

# %%
fraud_df.shape
# Out:
# (1048575, 12)

# %%
fraud_df.nunique()
# Out:
# step                   95
# type                    5
# amount            1009606
# nameOrig          1048317
# oldbalanceOrg      391033
# newbalanceOrig     440792
# oldbalanceDest     590110
# newbalanceDest     437054
# isFraud                 2
# same_value              2
# C                       2
# M                       2
# dtype: int64

# %%
## Label encoding of type feature
# def label_encoding(type):
#   if (type == "CASH_OUT"):
#     return 1
#   elif (type == "TRANSFER"):
#     return 1
#   else:
#     return 0

# fraud_df['type_label'] = fraud_df['type'].apply(label_encoding)
# pd.set_option('display.max_rows', None)
# fraud_df = fraud_df.drop(columns=['type'])
# fraud_df.head()

# %%
# One-hot encoding of type feature
# Get one hot encoding of column
one_hot = pd.get_dummies(fraud_df['type'], dtype=int)
# Drop column as it is now encoded
fraud_df = fraud_df.drop('type',axis = 1)
# Join the encoded dataset
fraud_df = fraud_df.join(one_hot)
fraud_df.head()
# Out:
#    step   amount     nameOrig  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1  9839.64  C1231006815      170136.00       160296.36            0.00
# 1     1  1864.28  C1666544295       21249.00        19384.72            0.00
# 2     1   181.00  C1305486145         181.00            0.00            0.00
# 3     1   181.00   C840083671         181.00            0.00        21182.00
# 4     1 11668.14  C2048537720       41554.00        29885.86            0.00
#
#    newbalanceDest  isFraud  same_value  C  M  CASH_IN  CASH_OUT  DEBIT  \
# 0            0.00        0           0  0  1        0         0      0
# 1            0.00        0           0  0  1        0         0      0
# 2            0.00        1           1  1  0        0         0      0
# 3            0.00        1           1  1  0        0         1      0
# 4            0.00        0           0  0  1        0         0      0
#
#    PAYMENT  TRANSFER
# 0        1         0
# 1        1         0
# 2        0         1
# 3        0         0
# 4        1         0

# %%
fraud_df.dtypes
# Out:
# step                int64
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# same_value          int64
# C                   int32
# M                   int32
# CASH_IN             int32
# CASH_OUT            int32
# DEBIT               int32
# PAYMENT             int32
# TRANSFER            int32
# dtype: object

# %%
# take all numeric cols and put in 1 dataframe
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = fraud_df.select_dtypes(include=numerics)
numeric_df.head()
# Out:
#    step   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1  9839.64      170136.00       160296.36            0.00
# 1     1  1864.28       21249.00        19384.72            0.00
# 2     1   181.00         181.00            0.00            0.00
# 3     1   181.00         181.00            0.00        21182.00
# 4     1 11668.14       41554.00        29885.86            0.00
#
#    newbalanceDest  isFraud  same_value  C  M  CASH_IN  CASH_OUT  DEBIT  \
# 0            0.00        0           0  0  1        0         0      0
# 1            0.00        0           0  0  1        0         0      0
# 2            0.00        1           1  1  0        0         0      0
# 3            0.00        1           1  1  0        0         1      0
# 4            0.00        0           0  0  1        0         0      0
#
#    PAYMENT  TRANSFER
# 0        1         0
# 1        1         0
# 2        0         1
# 3        0         0
# 4        1         0

# %%
# draw correlation matrix
numeric_df_corr = numeric_df.corr()
numeric_df_corr
highlight_table = numeric_df_corr.round(2).style.background_gradient(cmap='coolwarm')
highlight_table
# Out:
# <style  type="text/css" >
#     #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col1 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col5 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col7 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col8 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col9 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col10 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col12 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col13 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row0_col14 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col4 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col5 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col6 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col8 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col9 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col10 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col11 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col12 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col13 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row1_col14 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col4 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col6 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col8 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col9 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col10 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col11 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col13 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row2_col14 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col4 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col6 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col7 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col8 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col9 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col10 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col11 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col13 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_fdbbecc0_fafe_11ea_bf3b_54e1ad623274row3_col14 {
#             background-color:  #5b7ae5;

# %%
# save df as csv
numeric_df.to_csv('a2_b1_c1_d1.csv', index=False)

# %%
numeric_df = numeric_df.drop(['same_value'], axis=1)
numeric_df.to_csv('a1_b2_c2.csv', index=False)
